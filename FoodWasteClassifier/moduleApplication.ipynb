# %%
# %matplotlib qt
import cv2
import numpy as np
from datetime import datetime
from ultralytics import YOLO
import pandas as pd
from openpyxl import Workbook
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from collections import Counter
import os

# %%
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
excel_path = f"detection_statistics_{timestamp}.xlsx"
columns = ["Timestamp", "Rice", "Orange", "Nuts", "Beef", "Bread", "Fish"]

df = pd.DataFrame(columns=columns)
df.to_excel(excel_path, index=False)
print(f"Excel file created: {excel_path}")

model = YOLO("EcoBiteAIModel.pt")

cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Could not open camera.")
    exit()

detection_data_list = []

def collect_detection_data(detections):
    data = { "Timestamp": datetime.now().strftime('%Y-%m-%d %H:%M:%S'), "Rice": 0, "Orange": 0, "Nuts": 0, "Beef": 0, "Bread": 0, "Fish": 0 }
    for detection in detections:
        class_id = int(detection.cls[0])
        label = model.names[class_id]
        if '_' in label:
            percentage, item = label.split('_')
            if item.capitalize() in data:
                data[item.capitalize()] = f"{percentage}%"
    detection_data_list.append(data)

fig, ax = plt.subplots()
plt.title("YOLO Detection Data - Real-Time Update")

def update_graph(frame):
    ax.clear()
    
    aggregated_data = Counter()
    for data in detection_data_list:
        for item, value in data.items():
            if item != "Timestamp":
                aggregated_data[item] += int(value.strip('%') if value else 0)
    
    labels = list(aggregated_data.keys())
    values = list(aggregated_data.values())
    
    ax.bar(labels, values, color='skyblue')
    plt.xlabel("Items")
    plt.ylabel("Detection Percentage")
    plt.ylim(0, 100 * len(detection_data_list))

ani = FuncAnimation(fig, update_graph, interval=1000)

while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    results = model(frame)

    annotated_frame = results[0].plot()
    cv2.imshow("EcoBite", annotated_frame)

    key = cv2.waitKey(1) & 0xFF
    if key == ord('s'):
        collect_detection_data(results[0].boxes)
    elif key == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
plt.close()

if detection_data_list:
    df = pd.DataFrame(detection_data_list)
    df.to_excel(excel_path, index=False, header=True)
    print(f"All collected detection data saved to {excel_path}")
else:
    print("No detection data to save.")
# Out:
# Excel file created: detection_statistics_20241107_033649.xlsx
#
# 0: 384x640 (no detections), 101.3ms
# Speed: 2.1ms preprocess, 101.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# /var/folders/fk/t7022ty177xf1p00rpp1g8j40000gn/T/ipykernel_2032/874838833.py:49: UserWarning: frames=None which we can infer the length of, did not pass an explicit *save_count* and passed cache_frame_data=True.  To avoid a possibly unbounded cache, frame data caching has been disabled. To suppress this warning either pass `cache_frame_data=False` or `save_count=MAX_FRAMES`.
#   ani = FuncAnimation(fig, update_graph, interval=1000)
# /var/folders/fk/t7022ty177xf1p00rpp1g8j40000gn/T/ipykernel_2032/874838833.py:47: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   plt.ylim(0, 100 * len(detection_data_list))
# 0: 384x640 (no detections), 88.9ms
# Speed: 1.9ms preprocess, 88.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 93.7ms
# Speed: 1.3ms preprocess, 93.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 83.5ms
# Speed: 1.7ms preprocess, 83.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 74.4ms
# Speed: 1.4ms preprocess, 74.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 87.0ms
# Speed: 2.4ms preprocess, 87.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 76.9ms
# Speed: 1.9ms preprocess, 76.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 67.5ms
# Speed: 1.4ms preprocess, 67.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 69.2ms
# Speed: 1.5ms preprocess, 69.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.4ms
# Speed: 1.4ms preprocess, 66.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 70.9ms
# Speed: 1.5ms preprocess, 70.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 66.3ms
# Speed: 1.2ms preprocess, 66.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 64.7ms
# Speed: 1.3ms preprocess, 64.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 empty, 66.3ms
# Speed: 1.4ms preprocess, 66.3ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_orange, 70.3ms
# Speed: 1.5ms preprocess, 70.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 empty, 67.2ms
# Speed: 1.3ms preprocess, 67.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 empty, 68.0ms
# Speed: 1.3ms preprocess, 68.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 emptys, 76.2ms
# Speed: 1.3ms preprocess, 76.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_orange, 3 emptys, 69.7ms
# Speed: 1.4ms preprocess, 69.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 emptys, 65.4ms
# Speed: 1.3ms preprocess, 65.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 emptys, 69.0ms
# Speed: 1.4ms preprocess, 69.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_nuts, 1 empty, 68.2ms
# Speed: 1.3ms preprocess, 68.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_nuts, 1 empty, 82.0ms
# Speed: 1.4ms preprocess, 82.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_rice, 1 empty, 79.2ms
# Speed: 1.4ms preprocess, 79.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_orange, 2 100_rices, 1 50_rice, 1 empty, 73.0ms
# Speed: 1.4ms preprocess, 73.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 50_rice, 1 empty, 74.5ms
# Speed: 1.3ms preprocess, 74.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 78.2ms
# Speed: 1.4ms preprocess, 78.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 empty, 73.2ms
# Speed: 1.5ms preprocess, 73.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 50_rice, 71.3ms
# Speed: 1.3ms preprocess, 71.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 50_rice, 1 empty, 73.7ms
# Speed: 1.4ms preprocess, 73.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 50_rice, 75.8ms
# Speed: 1.4ms preprocess, 75.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 empty, 78.0ms
# Speed: 1.5ms preprocess, 78.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 empty, 71.8ms
# Speed: 1.5ms preprocess, 71.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 50_rice, 1 empty, 68.4ms
# Speed: 1.6ms preprocess, 68.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 50_rice, 1 empty, 71.8ms
# Speed: 1.5ms preprocess, 71.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 50_rices, 1 empty, 68.9ms
# Speed: 1.3ms preprocess, 68.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 50_rice, 1 empty, 70.9ms
# Speed: 1.4ms preprocess, 70.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 1 empty, 74.0ms
# Speed: 1.5ms preprocess, 74.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 50_rices, 1 empty, 78.8ms
# Speed: 1.3ms preprocess, 78.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.7ms
# Speed: 1.3ms preprocess, 68.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_rice, 1 50_rice, 80.1ms
# Speed: 1.6ms preprocess, 80.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 50_rices, 75.4ms
# Speed: 1.5ms preprocess, 75.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 73.8ms
# Speed: 1.3ms preprocess, 73.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 2 50_breads, 1 empty, 70.1ms
# Speed: 1.4ms preprocess, 70.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 68.9ms
# Speed: 1.3ms preprocess, 68.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 2 25_nutss, 1 50_fish, 1 50_rice, 1 empty, 72.7ms
# Speed: 1.8ms preprocess, 72.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 1 25_nuts, 1 50_fish, 72.8ms
# Speed: 1.3ms preprocess, 72.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_orange, 1 100_rice, 1 50_rice, 74.7ms
# Speed: 1.3ms preprocess, 74.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 25_fishs, 1 50_fish, 2 50_rices, 1 empty, 76.1ms
# Speed: 1.3ms preprocess, 76.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 1 25_nuts, 1 50_fish, 1 50_rice, 1 empty, 72.7ms
# Speed: 1.4ms preprocess, 72.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_orange, 1 25_nuts, 1 empty, 69.4ms
# Speed: 1.5ms preprocess, 69.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 1 25_nuts, 1 50_fish, 1 50_rice, 2 emptys, 70.5ms
# Speed: 1.3ms preprocess, 70.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_orange, 1 25_fish, 2 50_rices, 1 empty, 70.9ms
# Speed: 1.4ms preprocess, 70.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_orange, 1 25_fish, 3 50_rices, 1 empty, 70.0ms
# Speed: 1.2ms preprocess, 70.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 2 50_rices, 1 empty, 69.2ms
# Speed: 1.3ms preprocess, 69.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_nuts, 1 25_fish, 3 50_rices, 1 empty, 70.2ms
# Speed: 1.3ms preprocess, 70.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 1 50_orange, 1 50_rice, 2 emptys, 69.6ms
# Speed: 1.3ms preprocess, 69.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_nuts, 1 100_orange, 2 25_fishs, 2 emptys, 71.7ms
# Speed: 1.3ms preprocess, 71.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 25_fish, 2 50_rices, 3 emptys, 71.1ms
# Speed: 1.7ms preprocess, 71.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 25_fish, 3 50_rices, 2 emptys, 69.1ms
# Speed: 1.3ms preprocess, 69.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_nuts, 1 25_fish, 1 empty, 69.0ms
# Speed: 1.3ms preprocess, 69.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_orange, 1 25_fish, 1 50_rice, 1 empty, 69.4ms
# Speed: 1.3ms preprocess, 69.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_nuts, 1 100_orange, 1 25_fish, 1 empty, 68.6ms
# Speed: 1.4ms preprocess, 68.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_nuts, 1 100_orange, 1 100_rice, 1 25_fish, 2 50_rices, 1 empty, 67.2ms
# Speed: 1.3ms preprocess, 67.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 2 50_rices, 1 empty, 67.3ms
# Speed: 1.3ms preprocess, 67.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 2 50_rices, 1 empty, 71.3ms
# Speed: 1.3ms preprocess, 71.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 50_fish, 1 50_rice, 3 emptys, 70.4ms
# Speed: 1.3ms preprocess, 70.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 1 50_fish, 2 50_rices, 3 emptys, 68.0ms
# Speed: 1.4ms preprocess, 68.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 1 50_fish, 2 50_rices, 2 emptys, 68.1ms
# Speed: 1.3ms preprocess, 68.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 2 25_nutss, 1 50_fish, 2 50_rices, 68.8ms
# Speed: 1.4ms preprocess, 68.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_orange, 1 25_fish, 3 25_nutss, 2 50_rices, 1 empty, 66.8ms
# Speed: 1.3ms preprocess, 66.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 66.5ms
# Speed: 1.3ms preprocess, 66.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_nuts, 1 50_fish, 1 50_rice, 1 empty, 68.7ms
# Speed: 1.3ms preprocess, 68.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 2 emptys, 66.7ms
# Speed: 1.3ms preprocess, 66.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 2 50_rices, 1 empty, 67.5ms
# Speed: 1.5ms preprocess, 67.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_orange, 1 100_rice, 1 50_fish, 2 50_rices, 1 empty, 68.4ms
# Speed: 1.5ms preprocess, 68.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 1 50_fish, 2 50_rices, 1 empty, 65.2ms
# Speed: 1.3ms preprocess, 65.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 1 50_fish, 2 50_rices, 2 emptys, 66.0ms
# Speed: 1.3ms preprocess, 66.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_orange, 1 25_fish, 1 50_rice, 2 emptys, 66.3ms
# Speed: 1.3ms preprocess, 66.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 1 50_rice, 2 emptys, 65.9ms
# Speed: 1.3ms preprocess, 65.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 100_nutss, 1 25_fish, 1 50_rice, 1 empty, 66.5ms
# Speed: 1.3ms preprocess, 66.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_orange, 1 25_fish, 1 50_rice, 1 empty, 67.9ms
# Speed: 1.3ms preprocess, 67.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_orange, 1 25_fish, 1 50_rice, 2 emptys, 70.5ms
# Speed: 1.3ms preprocess, 70.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 100_nutss, 1 100_orange, 1 100_rice, 1 25_fish, 2 50_rices, 1 empty, 68.8ms
# Speed: 1.3ms preprocess, 68.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_nuts, 1 25_fish, 1 50_rice, 2 emptys, 69.6ms
# Speed: 1.5ms preprocess, 69.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_nuts, 1 25_fish, 1 empty, 68.3ms
# Speed: 1.3ms preprocess, 68.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 2 50_rices, 1 empty, 81.7ms
# Speed: 1.3ms preprocess, 81.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 2 50_rices, 2 emptys, 70.6ms
# Speed: 1.8ms preprocess, 70.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 1 25_fish, 1 75_rice, 3 emptys, 70.8ms
# Speed: 1.3ms preprocess, 70.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 100_fishs, 1 100_orange, 1 100_rice, 2 25_fishs, 1 25_nuts, 1 50_fish, 2 emptys, 69.5ms
# Speed: 1.8ms preprocess, 69.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 100_fishs, 1 100_rice, 1 25_fish, 1 25_nuts, 1 50_fish, 2 emptys, 67.0ms
# Speed: 1.5ms preprocess, 67.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 25_fish, 3 emptys, 66.5ms
# Speed: 1.4ms preprocess, 66.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_orange, 1 100_rice, 1 50_fish, 1 75_rice, 1 empty, 71.7ms
# Speed: 1.5ms preprocess, 71.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 25_fish, 1 50_fish, 1 empty, 66.6ms
# Speed: 1.4ms preprocess, 66.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 1 50_orange, 1 75_rice, 2 emptys, 67.5ms
# Speed: 1.6ms preprocess, 67.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 50_fish, 1 empty, 66.4ms
# Speed: 1.6ms preprocess, 66.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 25_fish, 1 50_fish, 1 75_rice, 1 empty, 73.9ms
# Speed: 1.5ms preprocess, 73.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 2 25_fishs, 1 50_fish, 1 empty, 74.0ms
# Speed: 1.5ms preprocess, 74.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 4 25_fishs, 1 50_fish, 1 75_rice, 1 empty, 67.2ms
# Speed: 1.4ms preprocess, 67.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 100_fishs, 2 75_rices, 1 empty, 68.4ms
# Speed: 1.5ms preprocess, 68.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 25_fish, 1 50_fish, 1 75_rice, 2 emptys, 72.6ms
# Speed: 1.5ms preprocess, 72.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 1 empty, 70.3ms
# Speed: 1.4ms preprocess, 70.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 1 25_fish, 1 50_rice, 1 empty, 75.6ms
# Speed: 1.5ms preprocess, 75.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 1 50_rice, 1 empty, 70.4ms
# Speed: 1.5ms preprocess, 70.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 1 50_rice, 1 empty, 75.4ms
# Speed: 1.4ms preprocess, 75.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 25_fishs, 1 50_rice, 1 empty, 71.8ms
# Speed: 1.4ms preprocess, 71.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 1 empty, 69.7ms
# Speed: 1.4ms preprocess, 69.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 1 50_rice, 1 empty, 68.7ms
# Speed: 1.4ms preprocess, 68.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_orange, 1 25_fish, 1 50_rice, 1 75_rice, 1 empty, 67.8ms
# Speed: 1.6ms preprocess, 67.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_orange, 1 25_fish, 2 50_rices, 2 emptys, 69.0ms
# Speed: 1.6ms preprocess, 69.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 25_fish, 2 50_rices, 1 empty, 68.4ms
# Speed: 1.7ms preprocess, 68.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# 0: 384x640 1 100_fish, 1 100_rice, 3 emptys, 75.8ms
# Speed: 1.8ms preprocess, 75.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 1 empty, 69.1ms
# Speed: 1.4ms preprocess, 69.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 25_fishs, 1 50_rice, 2 emptys, 67.3ms
# Speed: 1.4ms preprocess, 67.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 1 50_fish, 2 50_rices, 1 empty, 67.9ms
# Speed: 1.6ms preprocess, 67.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 1 empty, 67.6ms
# Speed: 1.5ms preprocess, 67.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 1 50_rice, 1 empty, 66.2ms
# Speed: 1.4ms preprocess, 66.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_orange, 1 25_nuts, 1 50_fish, 1 empty, 67.8ms
# Speed: 1.5ms preprocess, 67.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 2 emptys, 66.9ms
# Speed: 1.5ms preprocess, 66.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_rice, 1 25_fish, 1 50_rice, 2 emptys, 75.6ms
# Speed: 1.5ms preprocess, 75.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 25_fishs, 1 25_nuts, 1 50_rice, 3 emptys, 78.3ms
# Speed: 1.6ms preprocess, 78.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 2 emptys, 75.4ms
# Speed: 1.6ms preprocess, 75.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 3 25_fishs, 1 25_nuts, 1 empty, 81.1ms
# Speed: 1.8ms preprocess, 81.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 3 25_fishs, 1 25_nuts, 1 empty, 78.9ms
# Speed: 1.7ms preprocess, 78.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 3 25_fishs, 1 25_nuts, 1 empty, 68.0ms
# Speed: 1.6ms preprocess, 68.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_rice, 3 25_fishs, 1 empty, 67.1ms
# Speed: 1.5ms preprocess, 67.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 1 25_fish, 1 50_fish, 3 50_rices, 1 empty, 71.2ms
# Speed: 1.5ms preprocess, 71.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 1 50_fish, 2 50_rices, 1 empty, 66.6ms
# Speed: 1.4ms preprocess, 66.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 2 100_rices, 1 25_fish, 2 50_rices, 1 empty, 68.0ms
# Speed: 1.3ms preprocess, 68.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_nuts, 1 100_rice, 1 25_fish, 1 50_rice, 1 empty, 65.6ms
# Speed: 1.4ms preprocess, 65.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 1 25_fish, 1 50_fish, 2 50_rices, 1 empty, 64.9ms
# Speed: 1.5ms preprocess, 64.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 25_fish, 1 50_fish, 3 50_rices, 1 empty, 66.8ms
# Speed: 1.5ms preprocess, 66.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 100_rices, 1 empty, 66.3ms
# Speed: 1.5ms preprocess, 66.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_orange, 1 100_rice, 1 25_fish, 2 emptys, 66.5ms
# Speed: 1.5ms preprocess, 66.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_rice, 1 25_fish, 1 50_fish, 1 50_rice, 2 emptys, 71.1ms
# Speed: 1.9ms preprocess, 71.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_rice, 2 emptys, 70.4ms
# Speed: 1.5ms preprocess, 70.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_orange, 1 100_rice, 3 emptys, 69.4ms
# Speed: 1.6ms preprocess, 69.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_rice, 2 25_fishs, 1 50_rice, 1 empty, 68.7ms
# Speed: 1.8ms preprocess, 68.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_rice, 1 50_rice, 1 empty, 69.8ms
# Speed: 1.4ms preprocess, 69.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_orange, 2 100_rices, 1 25_fish, 3 50_rices, 2 emptys, 70.1ms
# Speed: 1.5ms preprocess, 70.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_rice, 1 25_fish, 1 empty, 69.0ms
# Speed: 1.6ms preprocess, 69.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_rice, 1 25_fish, 1 50_rice, 2 emptys, 67.1ms
# Speed: 1.6ms preprocess, 67.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_rice, 2 25_fishs, 1 50_rice, 2 emptys, 67.8ms
# Speed: 1.5ms preprocess, 67.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 2 100_rices, 1 25_fish, 1 empty, 66.9ms
# Speed: 1.5ms preprocess, 66.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_rice, 2 25_fishs, 1 50_rice, 1 empty, 69.0ms
# Speed: 1.4ms preprocess, 69.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 100_fish, 1 100_rice, 3 25_fishs, 2 50_rices, 1 empty, 68.6ms
# Speed: 1.5ms preprocess, 68.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 100_rices, 1 25_fish, 1 50_fish, 2 50_rices, 2 emptys, 69.2ms
# Speed: 1.4ms preprocess, 69.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 emptys, 72.8ms
# Speed: 1.4ms preprocess, 72.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# All collected detection data saved to detection_statistics_20241107_033649.xlsx
